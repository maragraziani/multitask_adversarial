# %%
import numpy as np

# %%
history=np.load('../../results/NAREA/training_log.npy', allow_pickle=True).item()

# %%
history.keys()
# Out:
# ['loss', 'val_loss']

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(history['loss'])
plt.plot(history['val_loss'])
